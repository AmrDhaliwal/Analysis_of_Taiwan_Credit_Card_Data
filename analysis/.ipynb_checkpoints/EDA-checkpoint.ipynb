# %%
from Scripts.functions import load_and_process
import pandas as pd
import matplotlib.pylab as plt
import seaborn as sns

# %%
# Load in load_and_process function and create a dataframe
df = load_and_process(r'default of credit card clients.csv')

# %%
# First 5 rows of Dataset
df.head()
# Out:
#    ID  Limit_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_APR  PAY_MAY  PAY_JUN  \
# 1   1      20000    2          2         1   24        2        2       -1
# 2   2     120000    2          2         2   26       -1        2        0
# 3   3      90000    2          2         2   34        0        0        0
# 4   4      50000    2          2         1   37        0        0        0
# 5   5      50000    1          2         1   57       -1        0       -1
#
#    PAY_JUL  ...  BILL_AMT_JUL  BILL_AMT_AUG  BILL_AMT_SEPT  PAY_AMT_APR  \
# 1       -1  ...             0             0              0            0
# 2        0  ...          3272          3455           3261            0
# 3        0  ...         14331         14948          15549         1518
# 4        0  ...         28314         28959          29547         2000
# 5        0  ...         20940         19146          19131         2000
#
#    PAY_AMT_MAY  PAY_AMT_JUN  PAY_AMT_JUL  PAY_AMT_AUG  PAY_AMT_SEPT  DEFAULT
# ...

# %%
# Rows and number of columns
df.shape
# Out:
# (30000, 25)

# %%
# count, mean, standard deviation, min, and max
df.describe().T
# Out:
#                  count           mean            std       min       25%  \
# ID             30000.0   15000.500000    8660.398374       1.0   7500.75
# Limit_BAL      30000.0  167484.322667  129747.661567   10000.0  50000.00
# SEX            30000.0       1.603733       0.489129       1.0      1.00
# EDUCATION      30000.0       1.853133       0.790349       0.0      1.00
# MARRIAGE       30000.0       1.551867       0.521970       0.0      1.00
# AGE            30000.0      35.485500       9.217904      21.0     28.00
# PAY_APR        30000.0      -0.016700       1.123802      -2.0     -1.00
# PAY_MAY        30000.0      -0.133767       1.197186      -2.0     -1.00
# PAY_JUN        30000.0      -0.166200       1.196868      -2.0     -1.00
# PAY_JUL        30000.0      -0.220667       1.169139      -2.0     -1.00
# PAY_AUG        30000.0      -0.266200       1.133187      -2.0     -1.00
# PAY_SEPT       30000.0      -0.291100       1.149988      -2.0     -1.00
# ...

# %%
# Marital status (1 = married; 2 = single; 3 = others). 
df['MARRIAGE']
# Out:
# 1        1
# 2        2
# 3        2
# 4        1
# 5        1
#         ..
# 29996    1
# 29997    2
# 29998    2
# 29999    1
# 30000    1
# Name: MARRIAGE, Length: 30000, dtype: int32

# %%
# Min and Max for Marriage column
df['MARRIAGE'].max(), df['MARRIAGE'].min()
# Out:
# (3, 0)

# %% [markdown]
# When looking at the average for education of the credit card payments collected
# in Taiwan it seems half are married.

# %%
df['AGE']
# Out:
# 1        24
# 2        26
# 3        34
# 4        37
# 5        57
#          ..
# 29996    39
# 29997    43
# 29998    37
# 29999    41
# 30000    46
# Name: AGE, Length: 30000, dtype: int32

# %%
# Min and Max for Age column
df['AGE'].max(), df['AGE'].min()
# Out:
# (79, 21)

# %%
# Set theme for Seaborn plots
sns.set_theme(style='ticks', palette='pastel')

# %%
# Draw a nested boxplot to show Marriage by Age.
plt.figure(figsize=(15,10))

ax = sns.boxplot(x='MARRIAGE', y='AGE',
            data=df)
sns.despine(offset=10, trim=True)
ax.set(ylabel='AGE in Years')
plt.show()

# %%
# Distribution plot to show Age.
plt.figure(figsize=(20,15))

bx = sns.displot(df['AGE'], kde=False, bins=25)
bx.set(xlabel='AGE in Years')
plt.show()

# %%
# Replaced all 0's, 5 and 6's with the number 4 since 4 means other according to the
# original dataset and 5 and 6 weren't specified so, I 
df['EDUCATION'].replace({0: 4, 5: 4, 6: 4}, inplace=True)

# %%
df.describe().T
# Out:
#                  count           mean            std       min       25%  \
# ID             30000.0   15000.500000    8660.398374       1.0   7500.75
# Limit_BAL      30000.0  167484.322667  129747.661567   10000.0  50000.00
# SEX            30000.0       1.603733       0.489129       1.0      1.00
# EDUCATION      30000.0       1.842267       0.744494       1.0      1.00
# MARRIAGE       30000.0       1.551867       0.521970       0.0      1.00
# AGE            30000.0      35.485500       9.217904      21.0     28.00
# PAY_APR        30000.0      -0.016700       1.123802      -2.0     -1.00
# PAY_MAY        30000.0      -0.133767       1.197186      -2.0     -1.00
# PAY_JUN        30000.0      -0.166200       1.196868      -2.0     -1.00
# PAY_JUL        30000.0      -0.220667       1.169139      -2.0     -1.00
# PAY_AUG        30000.0      -0.266200       1.133187      -2.0     -1.00
# PAY_SEPT       30000.0      -0.291100       1.149988      -2.0     -1.00
# ...

# %%
# Created a scatter plot to show Age by BILL_AMT_APR.
plt.figure(figsize=(20,15))

cx = sns.scatterplot(data=df, x='AGE', y='BILL_AMT_APR', hue='MARRIAGE')
cx.set(xlabel='AGE in Years', ylabel='Bill_Amt_Apr in NT$')
plt.show()

# %%
# Created a scatter plot to show Age by PAY_AMT_APR.
plt.figure(figsize=(20,15))

dx = sns.scatterplot(data=df, x='AGE', y='PAY_AMT_APR', hue='MARRIAGE')
dx.set(xlabel='AGE in Years', ylabel='Pay_Amt_Apr in NT$')
plt.show()

# %%
# Created a box plot to show EDUCATION by BILL_AMT_APR.
plt.figure(figsize=(15,10))

ex = sns.boxplot(x='EDUCATION', y='BILL_AMT_APR',
            data=df)
sns.despine(offset=10, trim=True)
ex.set(ylabel='Bill_Amt_Apr in NT$')
plt.show()

# %%
# Created a scatter plot to show EDUCATION by PAY_AMT_APR with an AGE hue.
plt.figure(figsize=(20,15))

fx = sns.scatterplot(data=df, x='EDUCATION', y='PAY_AMT_APR', hue='AGE')
fx.set(ylabel='Pay_Amt_Apr in NT$')
plt.show()

# %%
# Created a scatter plot to show EDUCATION by PAY_AMT_AUG with an AGE hue.
plt.figure(figsize=(20,15))

gx = sns.scatterplot(data=df, x='EDUCATION', y='PAY_AMT_AUG', hue='AGE')
gx.set(ylabel='Pay_Amt_Aug in NT$')
plt.show()

# %%
# Created a scatter plot to show EDUCATION by BILL_AMT_APR with an AGE hue.
plt.figure(figsize=(20,15))

hx = sns.scatterplot(data=df, x='EDUCATION', y='BILL_AMT_APR', hue='AGE')
hx.set(ylabel='Bill_Amt_Apr in NT$')
plt.show()

# %%
# Created a scatter plot to show EDUCATION by BILL_AMT_AUG with an AGE hue.
plt.figure(figsize=(20,15))

ix = sns.scatterplot(data=df, x='EDUCATION', y='BILL_AMT_AUG', hue='AGE')
ix.set(ylabel='Bill_Amt_Aug in NT$')
plt.show()

# %%
# Histplot to show the credit card limits
plt.figure(figsize = (15,10))
plt.title('Credit Limit')
jx = sns.histplot(df['Limit_BAL'],kde=True,bins=200, color='orange')
jx.set(xlabel='Limit_Bal in NT$')
plt.show()

# %%
# A barplot to show Gender vs Limit balance and split by Default payments
plt.figure(figsize = (15,10))
lx = sns.barplot(x='SEX',y='Limit_BAL', hue='DEFAULT', data=df)
lx.set(xlabel='SEX by Gender', ylabel='Limit Balance by $')
plt.show()

# %%
# Countplot to show number of Males vs number of Females
plt.figure(figsize = (15,10))
sns.countplot(x='SEX',data=df)
plt.show()

# %%
# Countplot to show number of Defaults
plt.figure(figsize = (15,10))
sns.countplot(x='DEFAULT', hue='SEX', data=df)
plt.show()

# %%
# A scatterplot that shows Age by Credit limit with a hue Sex
plt.figure(figsize = (15,10))
kx = sns.stripplot(x='AGE', y='Limit_BAL', hue='SEX', data=df, jitter=True, dodge=True)
kx.set(xlabel='AGE in Years', ylabel='Credit limit by $')
plt.show()

# %%
# A boxplot showing correlation between AGE and Limit_BAL with SEX as the hue.
plt.figure(figsize=(20,15))

lx = sns.boxplot(data=df, x='AGE', y='Limit_BAL', hue='SEX')
lx.set(xlabel='AGE in Years', ylabel='Limit_Bal in NT$')
plt.show()

# %%
# export the clean and procesed data set
export = df.to_csv(r'data_for_Tableau.csv', index = False)

# %% [markdown]
# ## Does age matter for credit card limit? Who defaults on their credit payments more Males or Females?
# When looking at the boxplot that shows AGE vs Limit_BAL it's clear that age does matter for credit limit but, varies greatly. On average 21 to 29-year old’s have the lowest
# credit limit while those 58 and older have some of the highest credit limits in the data set.
# After looking at my EDA analysis it's clear that Females default more on their credit cards than Males. But
# this is only true for all those included in this dataset. Because their are more Females then Males in this dataset
# it could cause the data to be slightly skewed.
