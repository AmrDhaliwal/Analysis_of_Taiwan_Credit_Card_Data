# %%
import pandas as pd
import matplotlib.pylab as plt
import seaborn as sns

# %%
# Method chain wrapped in a function
# Has renamned columns and dropped Nan values and duplicates
def load_and_process(_):
    #Method 1 load csv file and drop for Nan values
    df1 = (
        pd.read_csv(r"C:\Users\Amrit\Desktop\School\data301\course-project-solo_119\data\data.raw\default of credit card clients.csv")
        .dropna()
    )
    # Method 2 rename all columns in Dataframe
    df2 = (
        df1
        .rename(columns={'Unnamed: 0': 'ID', 'X1': 'Limit_BAL', 'X2': 'SEX', 'X3': 'EDUCATION',
                           'X4': 'MARRIAGE', 'X5': 'AGE', 'X6': 'PAY_APR', 'X7': 'PAY_MAY',
                           'X8': 'PAY_JUN', 'X9': 'PAY_JUL', 'X10': 'PAY_AUG', 'X11': 'PAY_SEPT',
                           'X12': 'BILL_AMT_APR', 'X13': 'BILL_AMT_MAY', 'X14': 'BILL_AMT_JUN',
                           'X15': 'BILL_AMT_JUL', 'X16': 'BILL_AMT_AUG', 'X17': 'BILL_AMT_SEPT',
                           'X18': 'PAY_AMT_APR', 'X19': 'PAY_AMT_MAY', 'X20': 'PAY_AMT_JUN',
                           'X21': 'PAY_AMT_JUL', 'X22': 'PAY_AMT_AUG', 'X23': 'PAY_AMT_SEPT',
                           'Y': 'PAY_NEXT_MONTH'})
    )
    # Method 3 use .drop to remove duplicate names from Dataframe
    # Change floats to int
    df3 = (
        df2
        .drop(df2.index[0])
        .astype(int)
    )
    
    return df3

# %%
# Load in load_and_process function and create a dataframe
df = load_and_process(r'C:\Users\Amrit\Desktop\School\data301\course-project-solo_119\data\data.processed\Credit_Card_Data.csv')

# %%
# First 5 rows of Dataset
df.head()
# Out:
#    ID  Limit_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_APR  PAY_MAY  PAY_JUN  \
# 1   1      20000    2          2         1   24        2        2       -1
# 2   2     120000    2          2         2   26       -1        2        0
# 3   3      90000    2          2         2   34        0        0        0
# 4   4      50000    2          2         1   37        0        0        0
# 5   5      50000    1          2         1   57       -1        0       -1
#
#    PAY_JUL  ...  BILL_AMT_JUL  BILL_AMT_AUG  BILL_AMT_SEPT  PAY_AMT_APR  \
# 1       -1  ...             0             0              0            0
# 2        0  ...          3272          3455           3261            0
# 3        0  ...         14331         14948          15549         1518
# 4        0  ...         28314         28959          29547         2000
# 5        0  ...         20940         19146          19131         2000
#
#    PAY_AMT_MAY  PAY_AMT_JUN  PAY_AMT_JUL  PAY_AMT_AUG  PAY_AMT_SEPT  \
# ...

# %%
# Rows and number of columns
df.shape
# Out:
# (30000, 25)

# %%
# count, mean, standard deviation, min, and max
df.describe().T
# Out:
#                   count           mean            std       min       25%  \
# ID              30000.0   15000.500000    8660.398374       1.0   7500.75
# Limit_BAL       30000.0  167484.322667  129747.661567   10000.0  50000.00
# SEX             30000.0       1.603733       0.489129       1.0      1.00
# EDUCATION       30000.0       1.853133       0.790349       0.0      1.00
# MARRIAGE        30000.0       1.551867       0.521970       0.0      1.00
# AGE             30000.0      35.485500       9.217904      21.0     28.00
# PAY_APR         30000.0      -0.016700       1.123802      -2.0     -1.00
# PAY_MAY         30000.0      -0.133767       1.197186      -2.0     -1.00
# PAY_JUN         30000.0      -0.166200       1.196868      -2.0     -1.00
# PAY_JUL         30000.0      -0.220667       1.169139      -2.0     -1.00
# PAY_AUG         30000.0      -0.266200       1.133187      -2.0     -1.00
# PAY_SEPT        30000.0      -0.291100       1.149988      -2.0     -1.00
# ...

# %%
# Marital status (1 = married; 2 = single; 3 = others). 
df['MARRIAGE']
# Out:
# 1        1
# 2        2
# 3        2
# 4        1
# 5        1
#         ..
# 29996    1
# 29997    2
# 29998    2
# 29999    1
# 30000    1
# Name: MARRIAGE, Length: 30000, dtype: int32

# %%
# Min and Max for Marriage column
df['MARRIAGE'].max(), df['MARRIAGE'].min()
# Out:
# (3, 0)

# %% [markdown]
# When looking at the average for education of the credit card payments collected
# in Taiwan it seems half are married.

# %%
df['AGE']
# Out:
# 1        24
# 2        26
# 3        34
# 4        37
# 5        57
#          ..
# 29996    39
# 29997    43
# 29998    37
# 29999    41
# 30000    46
# Name: AGE, Length: 30000, dtype: int32

# %%
# Min and Max for Age column
df['AGE'].max(), df['AGE'].min()
# Out:
# (79, 21)

# %%
# Set theme for Seaborn plots
sns.set_theme(style="ticks", palette="pastel")

# %%
# Draw a nested boxplot to show Marriage by Age.
plt.figure(figsize=(15,10))

sns.boxplot(x="MARRIAGE", y="AGE",
            data=df)
sns.despine(offset=10, trim=True)

# %%
# Distribution plot to show Age.
plt.figure(figsize=(20,15))

sns.displot(df1['AGE'], kde=False, bins=25)

# %%
# Created a new dataframe for specific columns I'm interersted in
df1 = df.filter(['AGE', 'MARRIAGE', 'BILL_AMT_APR', 'PAY_AMT_APR', 'EDUCATION'], axis=1)

# %%
# Replaced all 0's, 5 and 6's with the number 4 since 4 means other according to the
# original dataset and 5 and 6 weren't specified so, I 
df1["EDUCATION"].replace({0: 4, 5: 4, 6: 4}, inplace=True)

# %%
df1.describe().T
# Out:
#                 count          mean           std       min      25%      50%  \
# AGE           30000.0     35.485500      9.217904      21.0    28.00     34.0
# MARRIAGE      30000.0      1.551867      0.521970       0.0     1.00      2.0
# BILL_AMT_APR  30000.0  51223.330900  73635.860576 -165580.0  3558.75  22381.5
# PAY_AMT_APR   30000.0   5663.580500  16563.280354       0.0  1000.00   2100.0
# EDUCATION     30000.0      1.842267      0.744494       1.0     1.00      2.0
#
#                   75%       max
# AGE              41.0      79.0
# MARRIAGE          2.0       3.0
# BILL_AMT_APR  67091.0  964511.0
# PAY_AMT_APR    5006.0  873552.0
# EDUCATION         2.0       4.0

# %%
# Created a scatter plot to show Age by BILL_AMT_APR.
plt.figure(figsize=(20,15))

sns.scatterplot(data=df1, x="AGE", y="BILL_AMT_APR", hue='MARRIAGE')
# Out:
# <AxesSubplot:xlabel='AGE', ylabel='BILL_AMT_APR'>

# %%
# Created a scatter plot to show Age by PAY_AMT_APR.
plt.figure(figsize=(20,15))

sns.scatterplot(data=df1, x="AGE", y="PAY_AMT_APR", hue='MARRIAGE')
# Out:
# <AxesSubplot:xlabel='AGE', ylabel='PAY_AMT_APR'>

# %%
# Created a box plot to show EDUCATION by BILL_AMT_APR.
plt.figure(figsize=(15,10))

sns.boxplot(x="EDUCATION", y="BILL_AMT_APR",
            data=df1)
sns.despine(offset=10, trim=True)

# %%
# Created a scatter plot to show EDUCATION by PAY_AMT_APR with an AGE hue.
plt.figure(figsize=(20,15))

sns.scatterplot(data=df1, x="EDUCATION", y="PAY_AMT_APR", hue='AGE')
# Out:
# <AxesSubplot:xlabel='EDUCATION', ylabel='PAY_AMT_APR'>
