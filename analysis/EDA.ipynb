# %%
import numpy as np
import pandas as pd
import matplotlib.pylab as plt
import seaborn as sns

# %%
# Method chain wrapped in a function
# Has renamned columns and dropped Nan values and duplicates
def load_and_process():
    #Method 1 load csv file and drop for Nan values
    df1 = (
        pd.read_csv(r"C:\Users\Amrit\Desktop\School\data301\course-project-solo_119\data\data.raw\default of credit card clients.csv")
        .dropna()
    )
    # Method 2 rename all columns in Dataframe
    df2 = (
        df1
        .rename(columns={'Unnamed: 0': 'ID', 'X1': 'Limit_BAL', 'X2': 'SEX', 'X3': 'EDUCATION',
                           'X4': 'MARRIAGE', 'X5': 'AGE', 'X6': 'PAY_APR', 'X7': 'PAY_MAY',
                           'X8': 'PAY_JUN', 'X9': 'PAY_JUL', 'X10': 'PAY_AUG', 'X11': 'PAY_SEPT',
                           'X12': 'BILL_AMT_APR', 'X13': 'BILL_AMT_MAY', 'X14': 'BILL_AMT_JUN',
                           'X15': 'BILL_AMT_JUL', 'X16': 'BILL_AMT_AUG', 'X17': 'BILL_AMT_SEPT',
                           'X18': 'PAY_AMT_APR', 'X19': 'PAY_AMT_MAY', 'X20': 'PAY_AMT_JUN',
                           'X21': 'PAY_AMT_JUL', 'X22': 'PAY_AMT_AUG', 'X23': 'PAY_AMT_SEPT',
                           'Y': 'PAY_NEXT_MONTH'})
    )
    # Method 3 use .drop to remove duplicate names from Dataframe
    # Change floats to int
    df3 = (
        df2
        .drop(df2.index[0])
        .astype(int)
    )
    
    return df3

# %%
# First 5 rows of Dataset
load_and_process().head()
# Out:
#    ID  Limit_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_APR  PAY_MAY  PAY_JUN  \
# 1   1      20000    2          2         1   24        2        2       -1
# 2   2     120000    2          2         2   26       -1        2        0
# 3   3      90000    2          2         2   34        0        0        0
# 4   4      50000    2          2         1   37        0        0        0
# 5   5      50000    1          2         1   57       -1        0       -1
#
#    PAY_JUL  ...  BILL_AMT_JUL  BILL_AMT_AUG  BILL_AMT_SEPT  PAY_AMT_APR  \
# 1       -1  ...             0             0              0            0
# 2        0  ...          3272          3455           3261            0
# 3        0  ...         14331         14948          15549         1518
# 4        0  ...         28314         28959          29547         2000
# 5        0  ...         20940         19146          19131         2000
#
#    PAY_AMT_MAY  PAY_AMT_JUN  PAY_AMT_JUL  PAY_AMT_AUG  PAY_AMT_SEPT  \
# 1          689            0            0            0             0
# 2         1000         1000         1000            0          2000
# 3         1500         1000         1000         1000          5000
# 4         2019         1200         1100         1069          1000
# 5        36681        10000         9000          689           679
#
#    PAY_NEXT_MONTH
# 1               1
# 2               1
# 3               0
# 4               0
# 5               0
#
# [5 rows x 25 columns]

# %%
# Rows and number of columns
load_and_process().shape
# Out:
# (30000, 25)

# %%
# count, mean, standard deviation, min, and max
load_and_process().describe().T
# Out:
#                   count           mean            std       min       25%  \
# ID              30000.0   15000.500000    8660.398374       1.0   7500.75
# Limit_BAL       30000.0  167484.322667  129747.661567   10000.0  50000.00
# SEX             30000.0       1.603733       0.489129       1.0      1.00
# EDUCATION       30000.0       1.853133       0.790349       0.0      1.00
# MARRIAGE        30000.0       1.551867       0.521970       0.0      1.00
# AGE             30000.0      35.485500       9.217904      21.0     28.00
# PAY_APR         30000.0      -0.016700       1.123802      -2.0     -1.00
# PAY_MAY         30000.0      -0.133767       1.197186      -2.0     -1.00
# PAY_JUN         30000.0      -0.166200       1.196868      -2.0     -1.00
# PAY_JUL         30000.0      -0.220667       1.169139      -2.0     -1.00
# PAY_AUG         30000.0      -0.266200       1.133187      -2.0     -1.00
# PAY_SEPT        30000.0      -0.291100       1.149988      -2.0     -1.00
# BILL_AMT_APR    30000.0   51223.330900   73635.860576 -165580.0   3558.75
# BILL_AMT_MAY    30000.0   49179.075167   71173.768783  -69777.0   2984.75
# BILL_AMT_JUN    30000.0   47013.154800   69349.387427 -157264.0   2666.25
# BILL_AMT_JUL    30000.0   43262.948967   64332.856134 -170000.0   2326.75
# BILL_AMT_AUG    30000.0   40311.400967   60797.155770  -81334.0   1763.00
# BILL_AMT_SEPT   30000.0   38871.760400   59554.107537 -339603.0   1256.00
# PAY_AMT_APR     30000.0    5663.580500   16563.280354       0.0   1000.00
# PAY_AMT_MAY     30000.0    5921.163500   23040.870402       0.0    833.00
# PAY_AMT_JUN     30000.0    5225.681500   17606.961470       0.0    390.00
# PAY_AMT_JUL     30000.0    4826.076867   15666.159744       0.0    296.00
# PAY_AMT_AUG     30000.0    4799.387633   15278.305679       0.0    252.50
# PAY_AMT_SEPT    30000.0    5215.502567   17777.465775       0.0    117.75
# PAY_NEXT_MONTH  30000.0       0.221200       0.415062       0.0      0.00
#
#                      50%        75%        max
# ID               15000.5   22500.25    30000.0
# Limit_BAL       140000.0  240000.00  1000000.0
# SEX                  2.0       2.00        2.0
# EDUCATION            2.0       2.00        6.0
# MARRIAGE             2.0       2.00        3.0
# AGE                 34.0      41.00       79.0
# PAY_APR              0.0       0.00        8.0
# PAY_MAY              0.0       0.00        8.0
# PAY_JUN              0.0       0.00        8.0
# PAY_JUL              0.0       0.00        8.0
# PAY_AUG              0.0       0.00        8.0
# PAY_SEPT             0.0       0.00        8.0
# BILL_AMT_APR     22381.5   67091.00   964511.0
# BILL_AMT_MAY     21200.0   64006.25   983931.0
# BILL_AMT_JUN     20088.5   60164.75  1664089.0
# BILL_AMT_JUL     19052.0   54506.00   891586.0
# BILL_AMT_AUG     18104.5   50190.50   927171.0
# BILL_AMT_SEPT    17071.0   49198.25   961664.0
# PAY_AMT_APR       2100.0    5006.00   873552.0
# PAY_AMT_MAY       2009.0    5000.00  1684259.0
# PAY_AMT_JUN       1800.0    4505.00   896040.0
# PAY_AMT_JUL       1500.0    4013.25   621000.0
# PAY_AMT_AUG       1500.0    4031.50   426529.0
# PAY_AMT_SEPT      1500.0    4000.00   528666.0
# PAY_NEXT_MONTH       0.0       0.00        1.0

# %%
# Marital status (1 = married; 2 = single; 3 = others). 
load_and_process()['MARRIAGE']
# Out:
# 1        1
# 2        2
# 3        2
# 4        1
# 5        1
#         ..
# 29996    1
# 29997    2
# 29998    2
# 29999    1
# 30000    1
# Name: MARRIAGE, Length: 30000, dtype: int32

# %%
load_and_process()['MARRIAGE'].max()
# Out:
# 3

# %%
load_and_process()['MARRIAGE'].min()
# Out:
# 0

# %% [markdown]
# When looking at the average for education of the credit card payments collected
# in Taiwan it seems have are married

# %%
load_and_process().max()
# Out:
# ID                  30000
# Limit_BAL         1000000
# SEX                     2
# EDUCATION               6
# MARRIAGE                3
# AGE                    79
# PAY_APR                 8
# PAY_MAY                 8
# PAY_JUN                 8
# PAY_JUL                 8
# PAY_AUG                 8
# PAY_SEPT                8
# BILL_AMT_APR       964511
# BILL_AMT_MAY       983931
# BILL_AMT_JUN      1664089
# BILL_AMT_JUL       891586
# BILL_AMT_AUG       927171
# BILL_AMT_SEPT      961664
# PAY_AMT_APR        873552
# PAY_AMT_MAY       1684259
# PAY_AMT_JUN        896040
# PAY_AMT_JUL        621000
# PAY_AMT_AUG        426529
# PAY_AMT_SEPT       528666
# PAY_NEXT_MONTH          1
# dtype: int32

# %%
load_and_process().min()
# Out:
# ID                     1
# Limit_BAL          10000
# SEX                    1
# EDUCATION              0
# MARRIAGE               0
# AGE                   21
# PAY_APR               -2
# PAY_MAY               -2
# PAY_JUN               -2
# PAY_JUL               -2
# PAY_AUG               -2
# PAY_SEPT              -2
# BILL_AMT_APR     -165580
# BILL_AMT_MAY      -69777
# BILL_AMT_JUN     -157264
# BILL_AMT_JUL     -170000
# BILL_AMT_AUG      -81334
# BILL_AMT_SEPT    -339603
# PAY_AMT_APR            0
# PAY_AMT_MAY            0
# PAY_AMT_JUN            0
# PAY_AMT_JUL            0
# PAY_AMT_AUG            0
# PAY_AMT_SEPT           0
# PAY_NEXT_MONTH         0
# dtype: int32

# %%
load_and_process()['MARRIAGE'].plot(kind='hist', bins=20, figsize=(12,6), facecolor='grey',edgecolor='black')
# Out:
# <AxesSubplot:ylabel='Frequency'>
